# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
dat : np.array = np.load('../TimingData/capture.npy').flatten()
u : np.array = np.roll(np.load('../TimingData/sent.npy').flatten(),shift=1)
x   = np.arange(len(dat))

plt.plot(x[:10],dat[:10],x[:10],u[:10])
plt.show()

# %%
s = -100
m = -1
dat : np.array = np.load('../TimingData/1_signal.npy').flatten()
x   = np.arange(len(dat))
u   : np.array = np.roll(np.load('../TimingData/1_bits.npy').flatten(),shift=0)


plt.plot(x[s:m],dat[s:m],x[s:m],u[s:m])
plt.legend(["Actual","Expected"])
plt.show()

# %%
time = np.load('../TimingData/1_capture.npy')
d    = np.diff(time)
print(d)
# Out:
# [15992 16833 17180 15891 16670 16715 16639 16795 17190 16047 16387 17175
#  16521 16735 16448]
