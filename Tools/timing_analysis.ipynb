# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
dat : np.array = np.load('../TimingData/signal.npy').flatten()
time : np.array = np.load('../TimingData/timing.npy').flatten()
x   = np.arange(len(dat))
m   = 24
u   = x % m

l   = 10
fig, ax1 = plt.subplots()

# Plot dat on the left y-axis
ax1.plot(x[:l*m], dat[:l*m], color='tab:blue', label='Signal')
ax1.set_ylabel(r'Signal [$\mathit{bit}$]', color='tab:blue')
ax1.tick_params(axis='y', labelcolor='tab:blue')

# Create a second y-axis sharing the same x-axis
ax2 = ax1.twinx()
ax2.plot(x[:l*m], time[:l*m], color='tab:red', label=r'Time $\mu s$',alpha=0.5)
ax2.set_ylabel(r'time [$\mu s$]', color='tab:red')
ax2.tick_params(axis='y', labelcolor='tab:red')

ax1.set_xlabel("Frame number")
ax2.set_xlabel("Frame number")
plt.title('System timing diagram')
plt.show()

# %%
dat : np.array = np.load('../TimingData/signal.npy').flatten()
x   = np.arange(len(dat))
l   = 10
m   = 24
u   = (x-2) % m

fig, ax1 = plt.subplots()
# Plot dat on the left y-axis
ax1.plot(x[:l*m], dat[:l*m]-u[:l*m], color='tab:blue', label='Signal')
ax1.set_ylabel(r'Signal Error [$\mathit{bit}_{\mathit{actual}} - \mathit{bit}_{\mathit{expected}}$]', color='tab:blue')
ax1.tick_params(axis='y', labelcolor='tab:blue')

# Create a second y-axis sharing the same x-axis
ax2 = ax1.twinx()
ax2.plot(x[:l*m], time[:l*m], color='tab:red', label=r'Time $\mu s$',alpha=0.5)
ax2.set_ylabel(r'time [$\mu s$]', color='tab:red')
ax2.tick_params(axis='y', labelcolor='tab:red')

ax1.set_xlabel("Frame number")
ax2.set_xlabel("Frame number")
plt.title('System timing diagram')
plt.show()

# %%
l = 4
m = 24

dat : np.array = np.load('../TimingData/signal.npy').flatten()[:l*m]
x   = np.arange(len(dat))
u   = (x-2) % m

plt.plot(x,dat,x,u)
plt.show()

# %%
dat1 = np.load('../TimingData/signal_delay.npy')[1:]
dat2 = np.load('../TimingData/timing.npy')[1:]

plt.plot(dat)
plt.show()
